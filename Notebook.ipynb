# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Riccardo Rusciano
# Finance sector

# %% [markdown]
# _I'm interested in data science because I think that the capabilty to read data so they're useful for a certain purpose is a skill which is becoming more and more
# relevant in today's world._

# %% [markdown]
# ### The following code takes a number as input and returns its factorial

# %%
def fact(x):
    y = 1
    i = 1
    while i <= x:
        y = y*i
        i += 1
    return y
a = int(input("insert a number >=0: "))
f = fact(a)
print(f)
# Out:
# insert a number >=0: 5
# 120

# %% [markdown]
# * one
# * two
# * three
#
# ["Marvelous" Marvin Hagler vs Tommy "The Hitman" Hearns](https://www.youtube.com/watch?v=HL2a2-8OHdg)
#
# Podium|Name|Age|Team
# ---|---|---|---
# 1|Leclerc|25|Ferrari
# 2|Hamilton|37|Mercedes
# 3|Verstappen|25|Red Bull
